# %%
import pandas as pd

meteorites = pd.read_csv('/content/omg/Meteorite_Landings_20240306.csv', nrows=5)
meteorites
# Out:
#        name   id nametype     recclass  mass (g)  fall  year    reclat  \
# 0    Aachen    1    Valid           L5        21  Fell  1880  50.77500
# 1    Aarhus    2    Valid           H6       720  Fell  1951  56.18333
# 2      Abee    6    Valid          EH4    107000  Fell  1952  54.21667
# 3  Acapulco   10    Valid  Acapulcoite      1914  Fell  1976  16.88333
# 4   Achiras  370    Valid           L6       780  Fell  1902 -33.16667
#
#      reclong           GeoLocation
# 0    6.08333     (50.775, 6.08333)
# 1   10.23333  (56.18333, 10.23333)
# 2 -113.00000    (54.21667, -113.0)
# 3  -99.90000     (16.88333, -99.9)
# 4  -64.95000   (-33.16667, -64.95)

# %%
meteorites.shape
# Out:
# (5, 10)

# %%
meteorites.name
# Out:
# 0      Aachen
# 1      Aarhus
# 2        Abee
# 3    Acapulco
# 4     Achiras
# Name: name, dtype: object

# %%
meteorites.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass (g)', 'fall', 'year',
#        'reclat', 'reclong', 'GeoLocation'],
#       dtype='object')

# %%
meteorites.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
import pandas as pd
meteorites=pd.read_csv('/content/omg/Meteorite_Landings_20240306.csv')
meteorites
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation
# ...

# %%
import requests
responses = requests.get(
    'https://data.nasa.gov/resourse/gh4g-9sfh.json',
    params={'$limit':50_000}
)
if responses.ok:
  payload = responses.json()
else:
    print(f"Request was not successful and returned code:{responses.status_code}.")
    payload = None
# Out:
# Request was not successful and returned code:404.
